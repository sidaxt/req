# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
! pip install semantic-kernel==0.4.6.dev0
# Out:
# ...
#    ---------------------------------------- 0.0/224.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/224.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/224.3 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/224.3 kB 219.4 kB/s eta 0:00:01
#    ---------- ---------------------------- 61.4/224.3 kB 297.7 kB/s eta 0:00:01
#    ------------------------------------ - 215.0/224.3 kB 875.2 kB/s eta 0:00:01
#    -------------------------------------- 224.3/224.3 kB 856.3 kB/s eta 0:00:00
# ...
#   Attempting uninstall: semantic-kernel
#     Found existing installation: semantic-kernel 0.5.1.dev0
#     Uninstalling semantic-kernel-0.5.1.dev0:
#       Successfully uninstalled semantic-kernel-0.5.1.dev0
# ...

# %%
# !pip install 'pydantic<1.8.0'
# Out:
# StatementMeta(, 0f45b83a-43a1-4f22-acff-045f481bec8c, 7, Finished, Available)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.6.2
#     Uninstalling pydantic-2.6.2:
#       Successfully uninstalled pydantic-2.6.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chromadb 0.4.13 requires pydantic>=1.9, but you have pydantic 1.7.4 which is incompatible.
# openai 1.12.0 requires pydantic<3,>=1.9.0, but you have pydantic 1.7.4 which is incompatible.
# semantic-kernel 0.5.1.dev0 requires pydantic>2, but you have pydantic 1.7.4 which is incompatible.
# ...

# %%
pip install poetry
# Out:
# StatementMeta(, a9764769-595c-49c4-9e07-16eec8f7c413, 3, Finished, Available)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.9/248.9 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 38.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 514.7/514.7 kB 58.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 116.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.5/309.5 kB 111.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 164.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 21.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.11.0
#     Uninstalling filelock-3.11.0:
#       Successfully uninstalled filelock-3.11.0
# ...

# %%
poetry install pydantic
# Out:
# StatementMeta(, a9764769-595c-49c4-9e07-16eec8f7c413, 5, Finished, Available)
#   Cell In[14], line 1
#     poetry install pydantic
#            ^
# SyntaxError: invalid syntax

# %%
from pydantic import BaseModel
# Out:
# StatementMeta(, a9764769-595c-49c4-9e07-16eec8f7c413, 6, Finished, Available)

# %%
import semantic_kernel as sk
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion,OpenAIChatCompletion
from semantic_kernel import semantic_functions
#from semantic_kernel.kernel_extensions.import_semantic_skill_from_directory import import_semantic_skill_from_directory

# %%
# import os
# import sys
# import json
import pandas as pd

# %%
kernel = sk.Kernel()

# %%
deployment = "gpt35turbo16k"
api_key = "5d69dd6f0aa14121ae81066435443abf"
endpoint = "https://openai-poc-east.openai.azure.com/"
# base_url = "https://openai-poc-east.openai.azure.com/openai/deployments/gpt35turbo16k"
api_version = "2023-03-15-preview"

# %%
kernel.add_chat_service("chat", AzureChatCompletion(
                                deployment_name=deployment, 
                                endpoint = endpoint,
                                # base_url = base_url, 
                                api_key = api_key,
                                api_version = api_version))
# Out:
# Kernel(plugins=KernelPluginCollection(plugins={}), prompt_template_engine=PromptTemplateEngine(), memory=NullMemory(), text_completion_services={'chat': <function Kernel.add_text_completion_service.<locals>.<lambda> at 0x000001E2E24FCB80>}, chat_services={'chat': <function Kernel.add_chat_service.<locals>.<lambda> at 0x000001E2E24FCAE0>}, text_embedding_generation_services={}, default_text_completion_service='chat', default_chat_service='chat', default_text_embedding_generation_service=None, retry_mechanism=PassThroughWithoutRetry(), function_invoking_handlers={}, function_invoked_handlers={})

# %%
# base_skills_directory = '/lakehouse/default/Files/Skills'
base_skills_directory = 'Files/Skills'

# %%
skills = {
    **kernel.import_semantic_skill_from_directory(base_skills_directory , "dataskill"),
}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 skills = {
# ----> 2     **kernel.import_semantic_skill_from_directory(base_skills_directory , "dataskill"),
#       3 }
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pydantic\main.py:767, in BaseModel.__getattr__(self, item)
#     764     return super().__getattribute__(item)  # Raises AttributeError if appropriate
#     765 else:
#     766     # this is the current error
# --> 767     raise AttributeError(f'{type(self).__name__!r} object has no attribute {item!r}')
#
# AttributeError: 'Kernel' object has no attribute 'import_semantic_skill_from_directory'

# %%
df = pd.read_csv("/lakehouse/default/Files/Skills/csv/ProductList_Updated.csv")

# %%
pip list
# Out:
# Package                                      Version
# -------------------------------------------- ------------
# aiofiles                                     23.2.1
# aiohttp                                      3.8.5
# aioodbc                                      0.5.0
# aiosignal                                    1.3.1
# annotated-types                              0.6.0
# anyio                                        3.7.1
# asgiref                                      3.7.2
# asttokens                                    2.4.1
# async-timeout                                4.0.3
# attrs                                        23.1.0
# azure-common                                 1.1.28
# azure-core                                   1.29.5
# azure-core-tracing-opentelemetry             1.0.0b11
# azure-identity                               1.13.0
# azure-monitor-opentelemetry                  1.0.0b15
# azure-monitor-opentelemetry-exporter         1.0.0b16
# ...
