# %%
# Setup key accesses to Azure AI Services
ai_services_key = "4iRP6jNeg10fJCGmClo66QyxbhHeeVBKw14RISpNDVAzSeCi5y1J" # your AI Services key
ai_services_location = "https://poc-openai-cogsrch.search.windows.net" # your AI Services location

#poc-openai-cogsrch

# Setup key access to Azure Open AI Services
aoai_service_name = "OpenAI-PoC-East" # your Open AI service name
aoai_endpoint = "https://OpenAI-PoC-East.openai.azure.com" # your Open AI endpoint
aoai_key = "5d69dd6f0aa14121ae81066435443abf" # your Open AI key
aoai_version = "2023-03-15-preview"
# "gpt35turbo16k"
aoai_deployment_name_embeddings = "text-embedding-ada-002"
aoai_deployment_name_query = "text-davinci-003"
aoai_model_name_query = "text-davinci-003"

# Azure Cognitive Search
cogsearch_name = "poc-openai-cogsrch" # your cognitive search name
cogsearch_index_name = "complaince-policy-search" 
# your index name: must only contain lowercase, numbers, and dashes
cogsearch_api_key = "TBpoXA6at3L38HsBWSRHnZWfstC07Txt7kDulY7ccDAzSeAHslm9" # your api key with admin key

# %%
# Import required libraries from PySpark
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.context import SparkContext,SparkConf
from pyspark.sql.session import SparkSession


conf = SparkConf().setMaster("local").setAppName("sparkproject")
sc = SparkContext.getOrCreate(conf=conf)
sqlContext = SQLContext(sc)

# sc = SparkContext('local')
# conf = SparkConf().setMaster("local").setAppName("sparkproject")
# sc = SparkContext.getOrCreate(conf=conf)
# sc = SparkContext.getOrCreate()
# spark = SparkSession(sc)

document_path = "https://sapocopenai.blob.core.windows.net/policydocs/COM-POL-008 Financial Support to Professional and Patient Org. Medical Ed Co. Health Care Institutions.pdf" # path to your document
df = (
    sqlContext.read.format("binaryFile")
    .load(document_path)
    .limit(10)
    .cache()
)
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[2], line 9
#       5 from pyspark.sql.session import SparkSession
#       8 conf = SparkConf().setMaster("local").setAppName("sparkproject")
# ----> 9 sc = SparkContext.getOrCreate(conf=conf)
#      10 sqlContext = SQLContext(sc)
#      12 # sc = SparkContext('local')
#      13 # conf = SparkConf().setMaster("local").setAppName("sparkproject")
#      14 # sc = SparkContext.getOrCreate(conf=conf)
#      15 # sc = SparkContext.getOrCreate()
#      16 # spark = SparkSession(sc)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyspark\context.py:515, in SparkContext.getOrCreate(cls, conf)
#     513 with SparkContext._lock:
#     514     if SparkContext._active_spark_context is None:
# --> 515         SparkContext(conf=conf or SparkConf())
# ...

# %%
pip install pyspark
# Out:
# ...
#      ---------------------------------------- 0.0/317.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/317.0 MB ? eta -:--:--
#      -------------------------------------- 0.0/317.0 MB 145.2 kB/s eta 0:36:22
#      -------------------------------------- 0.0/317.0 MB 196.9 kB/s eta 0:26:50
#      -------------------------------------- 0.1/317.0 MB 252.2 kB/s eta 0:20:57
#      -------------------------------------- 0.1/317.0 MB 364.4 kB/s eta 0:14:30
#      ---------------------------------------- 0.6/317.0 MB 1.7 MB/s eta 0:03:05
#      --------------------------------------- 4.1/317.0 MB 10.8 MB/s eta 0:00:30
#       -------------------------------------- 7.2/317.0 MB 17.1 MB/s eta 0:00:19
#      - ------------------------------------ 10.5/317.0 MB 65.2 MB/s eta 0:00:05
#      - ------------------------------------ 13.8/317.0 MB 65.6 MB/s eta 0:00:05
# ...
