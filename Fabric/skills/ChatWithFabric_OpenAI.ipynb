# %%
! pip install semantic-kernel
# ==0.3.15.dev0
# ==0.4.6.dev0
# ==0.5.1.dev0
# ==0.3.15.dev0
# ! pip3 install semantic-kernel==0.4.6.dev0
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 14, Finished, Available)
# ...

# %%
pip list
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 15, Finished, Available)
# Package                       Version
# ----------------------------- ------------------
# absl-py                       2.0.0
# adal                          1.2.7
# adlfs                         2023.4.0
# aiofiles                      23.2.1
# aiohttp                       3.8.6
# aiosignal                     1.3.1
# alembic                       1.12.0
# annotated-types               0.6.0
# ansi2html                     0.0.0
# anyio                         3.7.1
# appdirs                       1.4.4
# argon2-cffi                   23.1.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.3.0
# asgiref                       3.7.2
# astor                         0.8.1
# asttokens                     2.4.0
# astunparse                    1.6.3
# async-timeout                 4.0.3
# attrs                         23.1.0
# autopage                      0.5.2
# ...

# %%
# from pyspark.dbutils import DBUtils
# from pyspark.sql import SparkSession
 
# spark = SparkSession.builder.getOrCreate()
# dbutils = DBUtils(spark)

# dbutils.library.restartPython()

# %%
# import os
# os._exit(00)
# Out:
# StatementMeta(, , , Waiting, )
# InternalError: Ipython kernel exits with code 0. Please restart your session.

# %%
# import IPython

# IPython.Application.instance().kernel.do_shutdown(True) #automatically restarts kernel
# Out:
# StatementMeta(, , , Waiting, )
# {'status': 'ok', 'restart': True}

# %%
import os
# import sys
# import json
import pandas as pd
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 16, Finished, Available)

# %%
import asyncio
import semantic_kernel as sk
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

#,OpenAIChatCompletion
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 39, Finished, Available)

# %%
kernel = sk.Kernel()
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 36, Finished, Available)

# %%
deployment = "gpt35turbo16k"
api_key = "5d69dd6f0aa14121ae81066435443abf"
endpoint = "https://openai-poc-east.openai.azure.com/"
# base_url = "https://openai-poc-east.openai.azure.com/openai/deployments/gpt35turbo16k"
api_version = "2023-03-15-preview"
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 22, Finished, Available)

# %%
kernel.add_chat_service("chat", AzureChatCompletion(
                                deployment_name=deployment, 
                                endpoint = endpoint,
                                # base_url = base_url, 
                                api_key = api_key,
                                api_version = api_version))
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 23, Finished, Available)

# %%
# base_skills_directory = r'C:\Users\ssirish\OneDrive - Daiichi Sankyo\Documents\Files\PoCs_Coding\Fabric\skills\Files\Skills\'
# base_skills_directory = 'C:/Users/ssirish/OneDrive - Daiichi Sankyo/Documents/Files/PoCs_Coding/Fabric/skills/Files/Skills/'
# base_skills_directory = '/Files/Skills/'
# base_skills_directory = '/Fabric_PoC/FabricLakehousePoC.Lakehouse/Files/Skills/'
base_skills_directory = 'abfss://Fabric_PoC@onelake.dfs.fabric.microsoft.com/FabricLakehousePoC.Lakehouse/Files/Skills/'
# base_skills_directory = 'C:/Users/ssirish/OneLake - Microsoft/Fabric_PoC/FabricLakehousePoC.Lakehouse/Files/Skills/'
# base_skills_directory = 'https://onelake.dfs.fabric.microsoft.com/Fabric_PoC/FabricLakehousePoC.Lakehouse/Files/Skills/'
# dataskill
print(base_skills_directory)
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 33, Finished, Available)
# abfss://Fabric_PoC@onelake.dfs.fabric.microsoft.com/FabricLakehousePoC.Lakehouse/Files/Skills/

# %%
# skills = {
#     **kernel.import_semantic_skill_from_directory(base_skills_directory , "dataskill"),
# }
# Out:
# StatementMeta(, 4c37eae0-2203-42f1-8c98-b5a86a514b05, 64, Finished, Available)

# %%
skills = kernel.import_semantic_skill_from_directory(base_skills_directory, 'dataskill')
# import_semantic_plugin_from_directory
# import_semantic_skill_from_directory
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 41, Finished, Available)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 skills = kernel.import_semantic_skill_from_directory(base_skills_directory, 'dataskill')
#       2 # import_semantic_plugin_from_directory
#       3 # import_semantic_skill_from_directory
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/semantic_kernel/kernel.py:850, in Kernel.import_semantic_skill_from_directory(self, parent_directory, skill_directory_name)
#     847 skill_directory = os.path.abspath(skill_directory)
#     849 if not os.path.exists(skill_directory):
# --> 850     raise ValueError(f"Skill directory does not exist: {skill_directory_name}")
#     852 skill = {}
#     854 directories = glob.glob(skill_directory + "/*/")
#
# ValueError: Skill directory does not exist: dataskill

# %%
dirs = os.path.join(base_skills_directory,'dataskill')
finaldir = os.path.abspath(dirs)
# print(os.path.abspath(_file_),'basename')
print(dirs, 'dirs')
print(finaldir, 'finaldir')
print(os.path, 'os path')
os.path.exists(finaldir)
# Out:
# StatementMeta(, a41cd6fa-2419-424e-a6e8-31a255af1d27, 35, Finished, Available)
# abfss://Fabric_PoC@onelake.dfs.fabric.microsoft.com/FabricLakehousePoC.Lakehouse/Files/Skills/dataskill dirs
# /mnt/var/hadoop/tmp/nm-secondary-local-dir/usercache/trusted-service-user/appcache/application_1709203691747_0001/container_1709203691747_0001_01_000001/abfss:/Fabric_PoC@onelake.dfs.fabric.microsoft.com/FabricLakehousePoC.Lakehouse/Files/Skills/dataskill finaldir
# <module 'posixpath' from '/home/trusted-service-user/cluster-env/trident_env/lib/python3.10/posixpath.py'> os path
# False
